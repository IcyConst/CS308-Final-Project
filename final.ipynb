# %%
# %run detector.py --train -m cnn
# Out:
# The training model is: cnn
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Abdullah_Gul
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Adrien_Brody
# The current name is: Alejandro_Toledo
# The current name is: Alejandro_Toledo
# The current name is: Alejandro_Toledo
# The current name is: Alejandro_Toledo
# The current name is: Alejandro_Toledo
# ...
